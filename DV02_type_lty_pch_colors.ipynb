# %%
TSdata <- read.csv("./Data/MyData.csv")
summary(TSdata)
# Out:
#       date            Mkt_RF               RF          SmallGrowth
#  Min.   :197901   Min.   :-23.1400   Min.   :0.0000   Min.   :-32.7100
#  1st Qu.:198702   1st Qu.: -2.1500   1st Qu.:0.2500   1st Qu.: -4.1325
#  Median :199502   Median :  1.0450   Median :0.4200   Median :  0.9700
#  Mean   :199473   Mean   :  0.6019   Mean   :0.4409   Mean   :  0.7439
#  3rd Qu.:200303   3rd Qu.:  3.6075   3rd Qu.:0.6100   3rd Qu.:  5.0925
#  Max.   :201104   Max.   : 12.4300   Max.   :1.3500   Max.   : 56.9700

# %%
samp <- TSdata[1:8,]
samp
# Out:
#   date   Mkt_RF RF   SmallGrowth
# 1 197901  4.18  0.77 10.96
# 2 197902 -3.41  0.73 -2.09
# 3 197903  5.75  0.81 11.71
# 4 197904  0.05  0.80  3.27
# 5 197905 -2.18  0.82 -1.89
# 6 197906  3.88  0.81  7.40
# 7 197907  0.73  0.77  1.77
# 8 197908  5.70  0.77  9.32

# %% [markdown]
# # Plot Style details

# %% [markdown]
# ## type

# %%
par(mfrow = c(2,2))

plot(samp$date,samp$SmallGrowth,  # scatter plot
     type = "p",
     main = "type p")
plot(samp$date,samp$SmallGrowth,
     type = "l",
     main = "type l")
plot(samp$date,samp$SmallGrowth,
     type = "b",
     main = "type b")
plot(samp$date,samp$SmallGrowth,
     type = "c",
     main = "type c")
plot(samp$SmallGrowth ~ samp$date,
     type = "o",
     main = "type o")
plot(samp$SmallGrowth ~ samp$date,
     type = "h",
     main = "type h")
plot(samp$SmallGrowth ~ samp$date,
     type = "s", # left
     main = "type s")
plot(samp$SmallGrowth ~ samp$date,
     type = "S", # right
     main = "type S")
plot(samp$SmallGrowth ~ samp$date,
     type = "n",
     main = "type n")
# Out:
# Plot with title “type c”
# Plot with title “type S”
# Plot with title “type n”

# %% [markdown]
# ## lty

# %%
par(mfrow = c(2,2))

plot(samp$SmallGrowth ~ samp$date,
     type = "l",
     lty = 1, # lty = "solid"
     main = "lty = 1")
plot(samp$SmallGrowth ~ samp$date,
     type = "l",
     lty = 2, # lty = "dashed"
     main = "lty = 2")
plot(samp$SmallGrowth ~ samp$date,
     type = "l",
     lty = 3, # lty = "dotted"
     main = "lty = 3")
plot(samp$SmallGrowth ~ samp$date,
     type = "l",
     lty = 4, # lty = "dotdash"
     main = "lty = 4")
plot(samp$SmallGrowth ~ samp$date,
     type = "l",
     lty = 5, # lty = "longdash"
     main = "lty = 5")
plot(samp$SmallGrowth ~ samp$date,
     type = "l",
     lty = 6, # lty = "twodash"
     main = "lty = 6")
plot(samp$SmallGrowth ~ samp$date,
     type = "o",
     lty = 1,
     main = "lty = 1 & type o")
plot(samp$SmallGrowth ~ samp$date,
     type = "l",
     lty = 0, # lty = "blank"
     main = "lty = 0")
# Out:
# Plot with title “lty = 4”
# Plot with title “lty = 0”

# %% [markdown]
# ## pch

# %%
par(mfrow = c(2, 2))

plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 0,
     main = "pch = 0")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 1,
     cex = 2.5, # change size
     main = "pch = 1")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 2,
     main = "pch = 2")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 3,
     main = "pch = 3")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 4,
     main = "pch = 4")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 5,
     main = "pch = 5")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 6,
     main = "pch = 6")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 7,
     main = "pch = 7")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 8,
     main = "pch = 8")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 9,
     main = "pch = 9")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 10,
     main = "pch = 10")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 11,
     main = "pch = 11")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 12,
     main = "pch = 12")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 13,
     main = "pch = 13")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 14,
     main = "pch = 14")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 15,
     main = "pch = 15")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 16,
     main = "pch = 16")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 17,
     main = "pch = 17")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 18,
     main = "pch = 18")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 19,
     main = "pch = 19")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 20,
     main = "pch = 20")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 21,
     main = "pch = 21",
     bg = "red") # pch from 21 to 25 can be filled using the argument bg=
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 22,
     main = "pch = 22")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 23,
     main = "pch = 23")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 24,
     main = "pch = 24")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = 25,
     main = "pch = 25")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "*",
     main = "pch *")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = ".",
     main = "pch l")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "o",
     main = "pch o")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "O",
     main = "lty = 1")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "0",
     main = "pch 0")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "+",
     main = "pch +")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "-",
     main = "pch -")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "|",
     main = "pch |")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "%",
     main = "pch %")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "#",
     main = "pch #")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "a",
     main = "pch a")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "A",
     main = "pch A")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "?",
     main = "pch ?")
plot(samp$SmallGrowth ~ samp$date, type = "b", lty = 1,
     pch = "@",
     main = "pch @")
# Out:
# Plot with title “pch = 3”
# Plot with title “pch = 7”
# Plot with title “pch = 11”
# Plot with title “pch = 15”
# Plot with title “pch = 19”
# Plot with title “pch = 23”
# Plot with title “pch l”
# Plot with title “pch +”
# Plot with title “pch #”
# Plot with title “pch @”

# %% [markdown]
# pch = 0,square
# pch = 1,circle
# pch = 2,triangle point up
# pch = 3,plus
# pch = 4,cross
# pch = 5,diamond
# pch = 6,triangle point down
# pch = 7,square cross
# pch = 8,star
# pch = 9,diamond plus
# pch = 10,circle plus
# pch = 11,triangles up and down
# pch = 12,square plus
# pch = 13,circle cross
# pch = 14,square and triangle down
# pch = 15, filled square
# pch = 16, filled circle
# pch = 17, filled triangle point-up
# pch = 18, filled diamond
# pch = 19, solid circle
# pch = 20,bullet (smaller circle)
# pch = 21, filled circle blue
# pch = 22, filled square blue
# pch = 23, filled diamond blue
# pch = 24, filled triangle point-up blue
# pch = 25, filled triangle point down blue

# %% [markdown]
# ## colors

# %%
par(mfrow = c(2, 2))

plot(samp$date,samp$SmallGrowth,  
     type = "l",
     col = "darksalmon")

plot(samp$date,samp$SmallGrowth,  
     type = "l",
     col = "AZuRe3")

plot(samp$date,samp$SmallGrowth,  
     type = "l",
     col = "brown   3")

plot(samp$date,samp$SmallGrowth,  
     type = "l",
     col = "burly    wood")
# Out:
# plot without title

# %%
length(colors())
# Out:
# [1] 657

# %%
print(colors())
# Out:
#   [1] "white"                "aliceblue"            "antiquewhite"
#   [4] "antiquewhite1"        "antiquewhite2"        "antiquewhite3"
#   [7] "antiquewhite4"        "aquamarine"           "aquamarine1"
#  [10] "aquamarine2"          "aquamarine3"          "aquamarine4"
#  [13] "azure"                "azure1"               "azure2"
#  [16] "azure3"               "azure4"               "beige"
#  [19] "bisque"               "bisque1"              "bisque2"
#  [22] "bisque3"              "bisque4"              "black"
#  [25] "blanchedalmond"       "blue"                 "blue1"
#  [28] "blue2"                "blue3"                "blue4"
#  [31] "blueviolet"           "brown"                "brown1"
#  [34] "brown2"               "brown3"               "brown4"
#  [37] "burlywood"            "burlywood1"           "burlywood2"
#  [40] "burlywood3"           "burlywood4"           "cadetblue"
#  [43] "cadetblue1"           "cadetblue2"           "cadetblue3"
# ...
