# %%
library(ggplot2)

# %%
qplot(Sepal.Length, Petal.Length, data=iris,
     col=Species)
# Out:
# plot without title

# %%
qplot(Sepal.Length, Petal.Length, data=iris,
     col=Species, size = Petal.Width)
# Out:
# plot without title
